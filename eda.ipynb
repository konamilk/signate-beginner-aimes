# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./input/train.csv')

# %%
df
# Out:
#       index  Order  MS SubClass MS Zoning  Lot Area Lot Shape Land Contour  \
# 0       200   2163           20        RL      9000       Reg          Lvl
# 1      3832   1862           20        RL      9600       Reg          Lvl
# 2      4927    754           20        RL      9600       Reg          Lvl
# 3      4088    641           80        RL      9600       Reg          Lvl
# 4      3644    754           20        RL      9600       Reg          Lvl
# ...     ...    ...          ...       ...       ...       ...          ...
# 2995   4931     27          120        RL      1680       Reg          Lvl
# 2996   3264   2203          160        RL      2665       Reg          Lvl
# 2997   1653   2447           20        RL      7200       Reg          Lvl
# 2998   2607    378           60        FV      9000       Reg          Lvl
# 2999   2732   2284           20        RL      9600       Reg          Lvl
#
# ...

# %%
pd.set_option('display.max_columns', 50)
df.select_dtypes(include=[int, float])
# Out:
#       index  Order  MS SubClass  Lot Area  Overall Qual  Overall Cond  \
# 0       200   2163           20      9000             5             5
# 1      3832   1862           20      9600             7             5
# 2      4927    754           20      9600             9             5
# 3      4088    641           80      9600             6             6
# 4      3644    754           20      9600             7             5
# ...     ...    ...          ...       ...           ...           ...
# 2995   4931     27          120      1680             5             5
# 2996   3264   2203          160      2665             5             5
# 2997   1653   2447           20      7200             5             5
# 2998   2607    378           60      9000             6             5
# 2999   2732   2284           20      9600             5             5
#
#       Year Built  Year Remod/Add  BsmtFin SF 1  Bsmt Unf SF  Total Bsmt SF  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 47 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           3000 non-null   int64
#  1   Order           3000 non-null   int64
#  2   MS SubClass     3000 non-null   int64
#  3   MS Zoning       3000 non-null   object
#  4   Lot Area        3000 non-null   int64
#  5   Lot Shape       3000 non-null   object
#  6   Land Contour    3000 non-null   object
#  7   Lot Config      3000 non-null   object
#  8   Neighborhood    3000 non-null   object
#  9   Bldg Type       3000 non-null   object
#  10  House Style     3000 non-null   object
#  11  Overall Qual    3000 non-null   int64
#  12  Overall Cond    3000 non-null   int64
#  13  Year Built      3000 non-null   int64
#  14  Year Remod/Add  3000 non-null   int64
#  15  Roof Style      3000 non-null   object
#  16  Exterior 1st    3000 non-null   object
# ...

# %%
df.describe()
# Out:
#              index        Order  MS SubClass      Lot Area  Overall Qual  \
# count  3000.000000  3000.000000  3000.000000   3000.000000   3000.000000
# mean   2492.964667  1248.236333    48.396667   7602.694000      5.815333
# std    1447.218078   839.778012    40.079273   2412.498362      1.073133
# min       0.000000    27.000000    20.000000   1680.000000      4.000000
# 25%    1218.750000   632.000000    20.000000   6000.000000      5.000000
# 50%    2465.500000  1097.000000    20.000000   8400.000000      6.000000
# 75%    3750.250000  2163.000000    60.000000   9600.000000      6.000000
# max    4999.000000  2902.000000   190.000000  31250.000000      9.000000
#
#        Overall Cond   Year Built  Year Remod/Add  BsmtFin SF 1  Bsmt Unf SF  \
# count   3000.000000  3000.000000     3000.000000   3000.000000  3000.000000
# mean       5.107333  1979.900667     1976.471667    517.089283   677.716410
# std        0.434982    25.464595       26.939323    432.542348   498.431545
# ...

# %%
df_numeric = df.select_dtypes(include=int)
df_numeric.columns
# Out:
# Index(['index', 'Order', 'MS SubClass', 'Lot Area', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', '1st Flr SF',
#        '2nd Flr SF', 'Gr Liv Area', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'TotRms AbvGrd', 'Fireplaces', 'Wood Deck SF',
#        'Open Porch SF', 'Mo Sold', 'Yr Sold', 'SalePrice'],
#       dtype='object')

# %%
numeric_columns = ['index', 'Order', 'MS SubClass', 'Lot Area', 'Overall Qual',
       'Overall Cond', 'Year Built', 'Year Remod/Add', '1st Flr SF',
       '2nd Flr SF', 'Gr Liv Area', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
       'Kitchen AbvGr', 'TotRms AbvGrd', 'Fireplaces', 'Wood Deck SF',
       'Open Porch SF', 'Mo Sold', 'Yr Sold', 'SalePrice']

# %%
df_string = df.select_dtypes(include=object)
df_string.columns
# Out:
# Index(['MS Zoning', 'Lot Shape', 'Land Contour', 'Lot Config', 'Neighborhood',
#        'Bldg Type', 'House Style', 'Roof Style', 'Exterior 1st',
#        'Exterior 2nd', 'Exter Qual', 'Foundation', 'Heating QC', 'Central Air',
#        'Electrical', 'Kitchen Qual', 'Paved Drive', 'Sale Type',
#        'Sale Condition'],
#       dtype='object')

# %%
string_columns = ['MS Zoning', 'Lot Shape', 'Land Contour', 'Lot Config', 'Neighborhood',
       'Bldg Type', 'House Style', 'Roof Style', 'Exterior 1st',
       'Exterior 2nd', 'Exter Qual', 'Foundation', 'Heating QC', 'Central Air',
       'Electrical', 'Kitchen Qual', 'Paved Drive', 'Sale Type',
       'Sale Condition']

# %%
df_figure = df_numeric.iloc[:,:9]

plt.figure(figsize=(14,10))
for i in np.arange((df_figure.shape[1])):
    plt.subplot(3,3,i+1)
    plt.boxplot(df_figure.iloc[:,i])
    plt.title(df_figure.columns[i])

# %%
df_figure = df_numeric.iloc[:,9:18]

plt.figure(figsize=(14,10))
for i in np.arange((df_figure.shape[1])):
    plt.subplot(3,3,i+1)
    plt.boxplot(df_figure.iloc[:,i])
    plt.title(df_figure.columns[i])

# %%
df_figure = df_numeric.iloc[:,18:]

plt.figure(figsize=(14,10))
for i in np.arange((df_figure.shape[1])):
    plt.subplot(3,3,i+1)
    plt.boxplot(df_figure.iloc[:,i])
    plt.title(df_figure.columns[i])

# %%
df_figure = df.iloc[:,:9]

plt.figure(figsize=(14,10))
for i in np.arange((df_figure.shape[1])):
    plt.subplot(3,3,i+1)
    plt.hist(df_figure.iloc[:,i], bins=30)
    plt.title(df_figure.columns[i])

# %%
df_figure = df.iloc[:,9:18]

plt.figure(figsize=(14,10))
for i in np.arange((df_figure.shape[1])):
    plt.subplot(3,3,i+1)
    plt.hist(df_figure.iloc[:,i], bins=30)
    plt.title(df_figure.columns[i])

# %%
df_figure = df.iloc[:,18:27]

plt.figure(figsize=(14,10))
for i in np.arange((df_figure.shape[1])):
    plt.subplot(3,3,i+1)
    plt.hist(df_figure.iloc[:,i], bins=50)
    plt.title(df_figure.columns[i])

# %%
df_figure = df.iloc[:,27:36]

plt.figure(figsize=(14,10))
for i in np.arange((df_figure.shape[1])):
    plt.subplot(3,3,i+1)
    plt.hist(df_figure.iloc[:,i], bins=50)
    plt.title(df_figure.columns[i])

# %%
df_figure = df.iloc[:,36:45]

plt.figure(figsize=(14,10))
for i in np.arange((df_figure.shape[1])):
    plt.subplot(3,3,i+1)
    plt.hist(df_figure.iloc[:,i], bins=50)
    plt.title(df_figure.columns[i])

# %%
df_figure = df.iloc[:,45:]

plt.figure(figsize=(14,10))
for i in np.arange((df_figure.shape[1])):
    plt.subplot(3,3,i+1)
    plt.hist(df_figure.iloc[:,i], bins=50)
    plt.title(df_figure.columns[i])

# %%
numeric_columns
# Out:
# ['index',
#  'Order',
#  'MS SubClass',
#  'Lot Area',
#  'Overall Qual',
#  'Overall Cond',
#  'Year Built',
#  'Year Remod/Add',
#  '1st Flr SF',
#  '2nd Flr SF',
#  'Gr Liv Area',
#  'Full Bath',
#  'Half Bath',
#  'Bedroom AbvGr',
#  'Kitchen AbvGr',
#  'TotRms AbvGrd',
#  'Fireplaces',
#  'Wood Deck SF',
#  'Open Porch SF',
#  'Mo Sold',
#  'Yr Sold',
#  'SalePrice']

# %%
def pre_process(df, phase='train'):
    df = df.drop(['index'], axis=1)
    df = df[df['MS SubClass'] < 150]
    df = df[df['Lot Area'] < 15000]
    df = df[df['1st Flr SF'] < 1800]
    df = df.drop(['Wood Deck SF'], axis=1)
    
    if(phase == 'train'):
        df = df[(df['SalePrice'] > 100000) & (df['SalePrice'] < 200000)]
    
    return df

# %%
df_preprocessed = pre_process(df, phase='train')

# %%
df_preprocessed
# Out:
#       Order  MS SubClass MS Zoning  Lot Area Lot Shape Land Contour  \
# 0      2163           20        RL      9000       Reg          Lvl
# 1      1862           20        RL      9600       Reg          Lvl
# 2       754           20        RL      9600       Reg          Lvl
# 3       641           80        RL      9600       Reg          Lvl
# 4       754           20        RL      9600       Reg          Lvl
# ...     ...          ...       ...       ...       ...          ...
# 2994    350           80        RL      9600       Reg          Lvl
# 2995     27          120        RL      1680       Reg          Lvl
# 2997   2447           20        RL      7200       Reg          Lvl
# 2998    378           60        FV      9000       Reg          Lvl
# 2999   2284           20        RL      9600       Reg          Lvl
#
#      Lot Config Neighborhood Bldg Type House Style  Overall Qual  \
# 0        Inside        NAmes      1Fam      1Story             5
# ...

# %%
df
# Out:
#       index  Order  MS SubClass MS Zoning  Lot Area Lot Shape Land Contour  \
# 0       200   2163           20        RL      9000       Reg          Lvl
# 1      3832   1862           20        RL      9600       Reg          Lvl
# 2      4927    754           20        RL      9600       Reg          Lvl
# 3      4088    641           80        RL      9600       Reg          Lvl
# 4      3644    754           20        RL      9600       Reg          Lvl
# ...     ...    ...          ...       ...       ...       ...          ...
# 2995   4931     27          120        RL      1680       Reg          Lvl
# 2996   3264   2203          160        RL      2665       Reg          Lvl
# 2997   1653   2447           20        RL      7200       Reg          Lvl
# 2998   2607    378           60        FV      9000       Reg          Lvl
# 2999   2732   2284           20        RL      9600       Reg          Lvl
#
#      Lot Config Neighborhood Bldg Type House Style  Overall Qual  \
# ...

# %%
# !grep Continuous ./input/data_description.txt
# Out:
# Lot Frontage (Continuous): Linear feet of street connected to property
# Lot Area (Continuous): Lot size in square feet
# Mas Vnr Area (Continuous): Masonry veneer area in square feet
# BsmtFin SF 1 (Continuous): Type 1 finished square feet
# BsmtFin SF 2 (Continuous): Type 2 finished square feet
# Bsmt Unf SF (Continuous): Unfinished square feet of basement area
# Total Bsmt SF (Continuous): Total square feet of basement area
# 1st Flr SF (Continuous): First Floor square feet
# 2nd Flr SF (Continuous)	: Second floor square feet
# Low Qual Fin SF (Continuous): Low quality finished square feet (all floors)
# Gr Liv Area (Continuous): Above grade (ground) living area square feet
# Garage Area (Continuous): Size of garage in square feet
# Wood Deck SF (Continuous): Wood deck area in square feet
# Open Porch SF (Continuous): Open porch area in square feet
# Enclosed Porch (Continuous): Enclosed porch area in square feet
# 3-Ssn Porch (Continuous): Three season porch area in square feet
# ...

# %%
# Continuous
df[['Lot Area','BsmtFin SF 1','Bsmt Unf SF','Total Bsmt SF','1st Flr SF','2nd Flr SF','Gr Liv Area','Garage Area','Wood Deck SF','Open Porch SF']]
# Out:
#       Lot Area  BsmtFin SF 1  Bsmt Unf SF  Total Bsmt SF  1st Flr SF  \
# 0         9000    554.725259   490.862838     620.339061         941
# 1         9600    514.217911  1711.943709    1286.011022         894
# 2         9600   1596.991227   511.217197    1341.741207         864
# 3         9600    586.182353   469.685845     566.069609         864
# 4         9600   1589.946047   484.337352    1258.013116         832
# ...        ...           ...          ...            ...         ...
# 2995      1680    620.110745   511.080630    1163.794125        1337
# 2996      2665      0.001057   480.872842     543.789909        1040
# 2997      7200    554.523591   488.283374     621.223013        1098
# 2998      9000      0.000872   504.687298     599.525621         728
# 2999      9600      0.001002   138.664835    -146.979773         864
#
#       2nd Flr SF  Gr Liv Area  Garage Area  Wood Deck SF  Open Porch SF
# ...
